# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
# 定義關鍵字
keywords = ['社論', '台電', '電價', '水費', '台塑', '塑化', '台化', '南亞', '台塑新智能', '水情', '碳費', '一分鐘看世界', 
            '兩岸快遞', '石油行情', '煤價', '浙電', '越電', '寧波', '越南', '風電', '光電', '水電', '儲能', '氫能', '能源', 
            '再生能源', '裝置容量', '綠電', '太陽能', '石油', '天然氣', 'LNG', '用電大戶', '充電樁', '碳稅', '碳權', '碳交易', 
            '火災', '中油', '地熱', '核電', '核能', '缺電', '備載容量', '停機', '海運費']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd

# 設置 Chrome 選項
chrome_options = Options()
chrome_options.add_argument("--headless")  # 無頭模式
driverpath = 'D:/chromedriver-win64/chromedriver-win64/chromedriver.exe'
# driverpath = 'C:/chromedriver-win64/chromedriver.exe'
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_experimental_option("prefs", {"profile.password_manager_enabled": False, "credentials_enable_service": False})

# 启动 Chrome 浏览器
service = Service(executable_path=driverpath)
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()

# 爬取目標網頁
driver.get("https://www.chinatimes.com/opinion/commercial/?chdtv")

# 等待頁面加載
driver.implicitly_wait(10)  # 最多等待 10 秒

# 查找新聞卡片元素
story_contents = driver.find_elements(By.CLASS_NAME, 'articlebox-compact')
news_data = []

# 提取標題和連結
for story_content in story_contents:
    title_tag = story_content.find_element(By.CLASS_NAME, 'title')
    link = title_tag.find_element(By.TAG_NAME, 'a')
    href = link.get_attribute('href')
    title = link.text.strip()
    news_data.append({'網站名稱': "中國時報", '標題': title, '連結': href})
    print("標題:", title)
    print("連結:", href)
    print()

# 將暫存列表轉換成 DataFrame
news_df = pd.DataFrame(news_data)

# 打印整個 DataFrame
news_df

# 關閉 WebDriver
driver.quit()
# Out:
# 標題: 工商社論》能源配置不調整 電價如何能不漲？
# 連結: https://www.chinatimes.com/opinion/20240704000207-262113
#
# 標題: 工商社論》智囊童子賢表態挺核 賴總統聽不聽？
# 連結: https://www.chinatimes.com/opinion/20240703000156-262113
#
# 標題: 工商社論》「草船借箭」的攬才計畫非長久之計提高生育率才是正辦
# 連結: https://www.chinatimes.com/opinion/20240702000138-262113
#
# 標題: 工商社論》探討新青安貸款「兩面刃」的風險
# 連結: https://www.chinatimes.com/opinion/20240701000131-262113
#
# 標題: 工商社論》AI應用之變革與可能引發之風險
# 連結: https://www.chinatimes.com/opinion/20240630000208-262113
#
# 標題: 工商社論》拜登的年紀與川普的嘴巴，救得了美國？
# 連結: https://www.chinatimes.com/opinion/20240629000175-262113
#
# 標題: 工商社論》改變監理思維 創造台灣金融市場新藍海
# 連結: https://www.chinatimes.com/opinion/20240628000151-262113
#
# 標題: 工商社論》打造科技島不能迴避的課題自然災害的損害控管
# 連結: https://www.chinatimes.com/opinion/20240627000155-262113

# %%
news_df
# Out:
#    網站名稱                              標題  \
# 0  中國時報           工商社論》能源配置不調整 電價如何能不漲？
# 1  中國時報          工商社論》智囊童子賢表態挺核 賴總統聽不聽？
# 2  中國時報  工商社論》「草船借箭」的攬才計畫非長久之計提高生育率才是正辦
# 3  中國時報            工商社論》探討新青安貸款「兩面刃」的風險
# 4  中國時報            工商社論》AI應用之變革與可能引發之風險
# 5  中國時報         工商社論》拜登的年紀與川普的嘴巴，救得了美國？
# 6  中國時報         工商社論》改變監理思維 創造台灣金融市場新藍海
# 7  中國時報      工商社論》打造科技島不能迴避的課題自然災害的損害控管
#
#                                                   連結
# 0  https://www.chinatimes.com/opinion/20240704000...
# 1  https://www.chinatimes.com/opinion/20240703000...
# 2  https://www.chinatimes.com/opinion/20240702000...
# 3  https://www.chinatimes.com/opinion/20240701000...
# 4  https://www.chinatimes.com/opinion/20240630000...
# 5  https://www.chinatimes.com/opinion/20240629000...
# 6  https://www.chinatimes.com/opinion/20240628000...
# 7  https://www.chinatimes.com/opinion/20240627000...
